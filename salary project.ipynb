# %% [markdown]
# # importing the library and DataSet

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Salary_Data')
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0      Prof          B             19           18  Male  139750
# 1      Prof          B             20           16  Male  173200
# 2  AsstProf          B              4            3  Male   79750
# 3      Prof          B             45           39  Male  115000
# 4      Prof          B             40           41  Male  141500

# %% [markdown]
# # Checking for Null Values

# %%
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# data set observed that no null values is present

# %% [markdown]
# # Description Of Data

# %% [markdown]
# predict the salary of the employee

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int64
# dtype: object

# %%
df['salary'].unique()
# Out:
# array([139750, 173200,  79750, 115000, 141500,  97000, 175000, 147765,
#        119250, 129000, 119800,  79800,  77700,  78000, 104800, 117150,
#        101000, 103450, 124750, 137000,  89565, 102580,  93904, 113068,
#         74830, 106294, 134885,  82379,  77000, 118223, 132261,  79916,
#        117256,  80225, 155750,  86373, 125196, 100938, 146500,  93418,
#        101299, 231545,  94384, 114778,  98193, 151768, 140096,  70768,
#        126621, 108875,  74692, 106639, 103760,  83900, 117704,  90215,
#        100135,  75044,  90304,  75243, 109785, 103613,  68404, 100522,
#         99418, 111512,  91412, 126320, 146856, 100131,  92391, 113398,
#         73266, 150480, 193000,  86100,  84240, 150743, 135585, 144640,
#         88825, 122960, 132825, 152708,  88400, 172272, 107008,  97032,
#        105128, 105631, 166024, 123683,  84000,  95611, 129676, 102235,
#        106689, 133217, 126933, 153303, 127512,  83850, 113543,  82099,
#         82600,  81500, 131205, 112429,  82100,  72500, 104279, 105000,
#        120806, 148500, 117515,  73500, 115313, 124309,  97262,  62884,
#         96614,  78162, 155500, 113278,  73000,  83001,  76840,  77500,
#        168635, 136000, 108262, 105668,  73877, 152664, 100102, 106608,
#         89942, 112696, 119015,  92000, 156938, 144651,  95079, 128148,
#        111168, 103994, 118971, 113341,  88000,  95408, 137167,  89516,
#        176500,  98510,  88795, 105890, 167284, 130664, 101210, 181257,
#         91227, 151575,  93164, 134185, 111751,  95436, 100944, 147349,
#        142467, 141136, 100000, 150000, 134000, 103750, 107500, 106300,
#        153750, 180000, 133700, 122100,  86250,  90000, 113600,  92700,
#        189409, 114500, 119700, 160400, 152500, 165000,  96545, 162200,
#        120000,  91300, 163200,  91000, 111350, 128400, 126200, 118700,
#        145350, 146000, 105350, 109650, 119500, 170000, 145200, 107150,
#        129600,  87800, 122400,  63900,  70000,  88175, 133900,  73300,
#        148750, 117555,  69700,  81700, 114000,  63100,  77202,  96200,
#         69200, 122875, 102600, 108200,  84273,  90450,  91100, 101100,
#        128800, 204000, 109000, 102000, 132000, 116450,  83000, 140300,
#         74000,  73800,  92550,  88600, 107550, 121200, 126000,  99000,
#        134800, 143940, 104350,  89650, 103700, 143250, 194800,  78500,
#         93000, 107200, 107100, 100600, 136500, 103600,  57800, 155865,
#         88650,  81800, 115800,  85000, 150500, 174500, 168500, 183800,
#        107300,  97150, 126300, 148800,  72300,  70700, 127100, 170500,
#        105260, 144050,  74500, 122500, 166800,  92050, 108100,  94350,
#        100351, 146800,  84716,  71065,  67559, 134550, 135027, 104428,
#         95642, 126431, 161101, 162221,  84500, 124714, 151650,  99247,
#        134778, 192253, 116518, 105450, 145098, 104542, 151445,  98053,
#        145000, 128464, 137317, 106231, 124312, 114596, 162150, 150376,
#        107986, 142023, 128250,  80139, 144309, 186960,  93519, 142500,
#        138000,  83600, 145028,  88709, 107309, 109954,  78785, 121946,
#        109646, 138771,  81285, 205500, 101036, 115435, 108413, 131950,
#        134690,  78182, 110515, 109707, 136660, 103275, 103649,  74856,
#         77081, 150680, 104121,  75996, 172505,  86895, 125192, 114330,
#        139219, 109305, 119450, 186023, 166605, 151292, 103106, 150564,
#        101738,  95329,  81035], dtype=int64)

# %%
df['salary'].nunique()
# Out:
# 371

# %%
df['salary']=df['salary'].astype(int)

# %%
df.dtypes
# Out:
# rank             object
# discipline       object
# yrs.since.phd     int64
# yrs.service       int64
# sex              object
# salary            int32
# dtype: object

# %% [markdown]
# # checking the distribution

# %%
sns.distplot(df['salary'],kde=True)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# # Encoding the DataFrame

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le=LabelEncoder()

list1=['discipline','sex','rank']
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))

df
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0       2           1             19           18    1  139750
# 1       2           1             20           16    1  173200
# 2       1           1              4            3    1   79750
# 3       2           1             45           39    1  115000
# 4       2           1             40           41    1  141500
# ..    ...         ...            ...          ...  ...     ...
# 392     2           0             33           30    1  103106
# 393     2           0             31           19    1  150564
# 394     2           0             42           25    1  101738
# 395     2           0             25           15    1   95329
# 396     1           0              8            4    1   81035
#
# [397 rows x 6 columns]

# %%
df
# Out:
#      rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0       2           1             19           18    1  139750
# 1       2           1             20           16    1  173200
# 2       1           1              4            3    1   79750
# 3       2           1             45           39    1  115000
# 4       2           1             40           41    1  141500
# ..    ...         ...            ...          ...  ...     ...
# 392     2           0             33           30    1  103106
# 393     2           0             31           19    1  150564
# 394     2           0             42           25    1  101738
# 395     2           0             25           15    1   95329
# 396     1           0              8            4    1   81035
#
# [397 rows x 6 columns]

# %%
df.head()
# Out:
#    rank  discipline  yrs.since.phd  yrs.service  sex  salary
# 0     2           1             19           18    1  139750
# 1     2           1             20           16    1  173200
# 2     1           1              4            3    1   79750
# 3     2           1             45           39    1  115000
# 4     2           1             40           41    1  141500

# %%
dfcor=df.corr()
dfcor
# Out:
#                    rank  discipline  yrs.since.phd  yrs.service       sex  \
# rank           1.000000   -0.086266       0.525500     0.447499  0.132492
# discipline    -0.086266    1.000000      -0.218087    -0.164599  0.003724
# yrs.since.phd  0.525500   -0.218087       1.000000     0.909649  0.148788
# yrs.service    0.447499   -0.164599       0.909649     1.000000  0.153740
# sex            0.132492    0.003724       0.148788     0.153740  1.000000
# salary         0.522207    0.156084       0.419231     0.334745  0.138610
#
#                  salary
# rank           0.522207
# discipline     0.156084
# yrs.since.phd  0.419231
# yrs.service    0.334745
# sex            0.138610
# salary         1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# dataset observed that yrs since phd and discipline are negetively correlated and yrs service and yrs since phd are positively correlated

# %% [markdown]
# # Cheking the skewness

# %%
df.skew()
# Out:
# rank            -1.151164
# discipline      -0.177684
# yrs.since.phd    0.300880
# yrs.service      0.650569
# sex             -2.709958
# salary           0.714568
# dtype: float64

# %% [markdown]
# # checking the outliners

# %%
df.dtypes
# Out:
# rank             int32
# discipline       int32
# yrs.since.phd    int64
# yrs.service      int64
# sex              int32
# salary           int32
# dtype: object

# %%
df.plot(kind='box',subplots=True)
# Out:
# rank                AxesSubplot(0.125,0.125;0.110714x0.755)
# discipline       AxesSubplot(0.257857,0.125;0.110714x0.755)
# yrs.since.phd    AxesSubplot(0.390714,0.125;0.110714x0.755)
# yrs.service      AxesSubplot(0.523571,0.125;0.110714x0.755)
# sex              AxesSubplot(0.656429,0.125;0.110714x0.755)
# salary           AxesSubplot(0.789286,0.125;0.110714x0.755)
# dtype: object

# %%
sns.pairplot(df)

# %% [markdown]
# separating the columns into features and target

# %%
features=df.drop('salary',axis=1)
target=df['salary']

# %% [markdown]
# # Scalling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lg=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.3,random_state=42)
    lg.fit(features_train,target_train)
    pred_train=lg.predict(features_train)
    pred_test=lg.predict(features_test)

# %%
features_train.shape
# Out:
# (277, 5)

# %%
target_train.shape
# Out:
# (277,)

# %%
features_test.shape
# Out:
# (120, 5)

# %%
target_test.shape
# Out:
# (120,)

# %%
lg.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
lg.coef_
# Out:
# array([17134.06131692, 17723.68579992,  1060.96212137,  -372.69067386,
#         4619.70348619])

# %%
lg.score(features_train,target_train)
# Out:
# 0.41796329470233706

# %%
pred=lg.predict(features_test)
print('predicted salary:',pred)
print('actual salary',target_test)
# Out:
# predicted salary: [104000.01466519 114642.83147843  79324.99869827  85910.8695625
#  137298.63721135 104592.80347504 138074.04983174  97538.7592993
#   83728.67109271 115757.73917315 121381.04106393 122787.86904822
#  134746.91239456 130902.83321045 119346.51181064  84849.90744113
#  145987.69515559  81504.03284121 130990.0165182   99230.88296799
#  125225.33192974 117023.22659463 139077.90205291 127061.70667149
#   76990.46150721 106642.04498171  99287.99286818  99976.2643157
#  122381.98277484 109824.93134582 120320.07894256 124362.56645478
#  142173.64724416 130187.48313541 134115.75084724 133887.31124645
#  126860.38783311 127377.28744515 124624.20165509 134058.68308192
#  115186.85185288 119574.95141143  92333.75219093 108448.38845079
#  137496.83385777 130530.1425366  128438.24956652 145615.00448173
#  145645.0357544  129499.2116879  111459.94511431  85538.17888864
#  124047.23949771 100604.26153617 133340.33822686  80876.03562075
#  121182.84441752 108763.96922445 125628.05387627  83473.3645461
#  120780.16460587 103159.15067981 116593.42602058  82625.26918963
#  133740.14966312 132883.45902527  89036.64602642 119719.2024845
#   89782.02737413  73491.99436943  83473.3645461  134545.55142129
#  116707.64582097 124221.52184344  90900.0993957  108075.69777694
#  123304.76866026  64628.44239775 146820.21767617 126571.88568698
#  119088.04093718 121354.21625299  87344.52235773  82295.01829748
#  105205.22785963 139766.17350043 121696.87565417 113152.068783
#  121841.12672724  86283.56023635 116909.00679424 118715.35026332
#   82625.26918963 125799.38357686  72431.03224806  71370.07012669
#   67871.60298892 103847.42212733 141542.48569684  74552.9564908
#  126316.32532378 132480.73707875  70309.10800532 144584.07363303
#  119229.12768339 128065.55889267 131134.22545639 147048.65727696
#  111144.36434066 130845.72331026 128291.08798319 126172.1163856
#  132967.68968788  85910.8695625  102098.18855844 127605.76918082
#  115905.15457306  77632.87502958 131476.88485757 126773.24666024]
# actual salary 114    105000
# 278    107100
# 237     63100
# 57      90215
# 72     100131
#         ...
# 283    155865
# 375    103649
# 253     77500
# 331    116518
# 109    131205
# Name: salary, Length: 120, dtype: int32

# %%
target_pred = lg.predict(features_test)

# %%
c = [i for i in range (1,len(target_test)+1,1)]
plt.plot(c,target_test,color='r',linestyle='-')
plt.plot(c,target_pred,color='b',linestyle='-')
plt.xlabel('salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()

# %%
print('error')
print('Mean absolute error:',mean_absolute_error(target_test,pred))
print('Mean squared erroe:',mean_squared_error(target_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(target_test,pred)))
# Out:
# error
# Mean absolute error: 18939.720711749174
# Mean squared erroe: 623415541.7434654
# Root Mean Squared Error: 24968.290725307277

# %%
pred_test=lg.predict(features_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(target_test,pred))
# Out:
# 0.22334860140435797

# %%
plt.figure(figsize=(12,6))
plt.scatter(target_test,target_pred,color='r',linestyle='-')
plt.show()
