# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('avacado_csv')

# %%
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 16463     NaN         NaN         NaN         NaN          NaN           NaN
# 16464     NaN         NaN         NaN         NaN          NaN           NaN
# 16465     NaN         NaN         NaN         NaN          NaN           NaN
# 16466     NaN         NaN         NaN         NaN          NaN           NaN
# 16467     NaN         NaN         NaN         NaN          NaN           NaN
#
#          year  region
# 0      2015.0  Albany
# 1      2015.0  Albany
# 2      2015.0  Albany
# 3      2015.0  Albany
# 4      2015.0  Albany
# ...       ...     ...
# 16463     NaN     NaN
# 16464     NaN     NaN
# 16465     NaN     NaN
# 16466     NaN     NaN
# 16467     NaN     NaN
#
# [16468 rows x 14 columns]

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# 3  2015.0  Albany
# 4  2015.0  Albany

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# relevent columns of dataset
#
# . Date - The date of the observation
#
# . AveragePrice - the average price of a single avocado
#
# . type - conventional or organic
#
# . year - the year
#
# . Region - the city or region of the observation
#
# . Total Volume - Total number of avocados sold
#
# . 4046 - Total number of avocados with PLU 4046 sold
#
# . 4225 - Total number of avocados with PLU 4225 sold
#
# . 4770 - Total number of avocados with PLU 4770 sold

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# # Null Value

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# data set has null values

# %%
data['Date'] =pd.to_datetime(data.Date)

data.sort_values(by=['Date'], inplace=True, ascending=True)

data.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume       4046       4225  \
# 1265        47.0 2015-01-02          0.71     916367.42  611270.39  205181.23
# 1111        47.0 2015-01-02          0.97     135656.36   35897.25   84741.31
# 1011        47.0 2015-01-02          0.91     469684.32  284674.20   78055.21
# 488         47.0 2015-01-02          0.92     245352.56    7245.61  181784.28
# 755         47.0 2015-01-02          1.14     569304.80   30263.22  417993.89
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1265  14107.36    85808.44    82065.70     3742.74          0.0  conventional
# 1111   2704.69    12313.11    12276.59       36.52          0.0  conventional
# 1011  27248.16    79706.75    51793.30    27913.45          0.0  conventional
# 488   14761.53    41561.14    20669.59    18130.75       2760.8  conventional
# 755    1722.10   119325.59   104365.66    14959.93          0.0  conventional
#
#         year            region
# 1265  2015.0  WestTexNewMexico
# 1111  2015.0           Spokane
# 1011  2015.0     SouthCarolina
# 488   2015.0      Indianapolis
# 755   2015.0      Philadelphia

# %%
data.drop('Total Bags',axis=1,inplace=True)
data.drop('Date',axis=1,inplace=True)
data.drop('type',axis=1,inplace=True)
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#       AveragePrice  Total Volume       4046       4225      4770  Small Bags  \
# 1265          0.71     916367.42  611270.39  205181.23  14107.36    82065.70
# 1111          0.97     135656.36   35897.25   84741.31   2704.69    12276.59
# 1011          0.91     469684.32  284674.20   78055.21  27248.16    51793.30
# 488           0.92     245352.56    7245.61  181784.28  14761.53    20669.59
# 755           1.14     569304.80   30263.22  417993.89   1722.10   104365.66
#
#       Large Bags  XLarge Bags    year            region
# 1265     3742.74          0.0  2015.0  WestTexNewMexico
# 1111       36.52          0.0  2015.0           Spokane
# 1011    27913.45          0.0  2015.0     SouthCarolina
# 488     18130.75       2760.8  2015.0      Indianapolis
# 755     14959.93          0.0  2015.0      Philadelphia

# %% [markdown]
# filling missing value

# %%
data['Total Volume'].fillna(data['Total Volume'].mean(),inplace=True)
data['AveragePrice'].fillna(data['AveragePrice'].mean(),inplace=True)
data['4046'].fillna(data['4046'].mean(),inplace=True)
data['4225'].fillna(data['4225'].mean(),inplace=True)
data['4770'].fillna(data['4770'].mean(),inplace=True)
data['year'].fillna(data['year'].mean(),inplace=True)
data['Small Bags'].fillna(data['Small Bags'].mean(),inplace=True)
data['Large Bags'].fillna(data['Large Bags'].mean(),inplace=True)
data['XLarge Bags'].fillna(data['XLarge Bags'].mean(),inplace=True)

# %%
data['region'].fillna(data['region'].mode()[0],inplace=True)

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# year            0
# region          0
# dtype: int64

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  16468.000000  1.646800e+04  1.646800e+04  1.646800e+04  1.646800e+04
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.057313  1.345098e+06  5.909424e+05  5.075910e+05  4.180541e+04
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# 50%        1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# 75%        1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Small Bags    Large Bags    XLarge Bags          year
# count  1.646800e+04  1.646800e+04   16468.000000  16468.000000
# mean   2.487736e+05  4.264205e+04    2181.771074   2015.162821
# std    1.964565e+05  3.586885e+04    2262.202563      0.112060
# min    3.311770e+03  0.000000e+00       0.000000   2015.000000
# 25%    2.487736e+05  4.264205e+04    2181.771074   2015.162821
# 50%    2.487736e+05  4.264205e+04    2181.771074   2015.162821
# 75%    2.487736e+05  4.264205e+04    2181.771074   2015.162821
# max    5.893642e+06  1.121076e+06  108072.790000   2016.000000

# %% [markdown]
# # checking for correlation

# %%
data.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.097682   -0.177480    -0.048284  0.178683
# Total Volume    0.960642    0.910226     0.521717 -0.004189
# 4046            0.922278    0.884229     0.474063 -0.040439
# 4225            0.943988    0.900496     0.504718 -0.007254
# 4770            0.923607    0.840523     0.646053  0.029222
# Small Bags      1.000000    0.879131     0.611300  0.106382
# Large Bags      0.879131    1.000000     0.447779 -0.018678
# XLarge Bags     0.611300    0.447779     1.000000  0.218342
# year            0.106382   -0.018678     0.218342  1.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='box',subplots=True)
# Out:
# AveragePrice       AxesSubplot(0.125,0.125;0.0731132x0.755)
# Total Volume    AxesSubplot(0.212736,0.125;0.0731132x0.755)
# 4046            AxesSubplot(0.300472,0.125;0.0731132x0.755)
# 4225            AxesSubplot(0.388208,0.125;0.0731132x0.755)
# 4770            AxesSubplot(0.475943,0.125;0.0731132x0.755)
# Small Bags      AxesSubplot(0.563679,0.125;0.0731132x0.755)
# Large Bags      AxesSubplot(0.651415,0.125;0.0731132x0.755)
# XLarge Bags     AxesSubplot(0.739151,0.125;0.0731132x0.755)
# year            AxesSubplot(0.826887,0.125;0.0731132x0.755)
# dtype: object

# %%
data['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# distribution of skewness

# %%
data.skew()
# Out:
# AveragePrice    -0.360270
# Total Volume    20.409801
# 4046            19.921599
# 4225            21.051013
# 4770            17.792883
# Small Bags      17.628360
# Large Bags      16.934805
# XLarge Bags     19.010574
# year             6.018559
# dtype: float64

# %%
sns.pairplot(data)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
others = data.select_dtypes('object').columns
others
# Out:
# Index(['region'], dtype='object')

# %%
le = LabelEncoder()
for col in others:
    data[col] = le.fit_transform(data[col])

# %%
data.select_dtypes('object').columns
# Out:
# Index([], dtype='object')

# %%
data.head()
# Out:
#       AveragePrice  Total Volume       4046       4225      4770  Small Bags  \
# 1265          0.71     916367.42  611270.39  205181.23  14107.36    82065.70
# 1111          0.97     135656.36   35897.25   84741.31   2704.69    12276.59
# 1011          0.91     469684.32  284674.20   78055.21  27248.16    51793.30
# 488           0.92     245352.56    7245.61  181784.28  14761.53    20669.59
# 755           1.14     569304.80   30263.22  417993.89   1722.10   104365.66
#
#       Large Bags  XLarge Bags    year  region
# 1265     3742.74          0.0  2015.0      50
# 1111       36.52          0.0  2015.0      44
# 1011    27913.45          0.0  2015.0      41
# 488     18130.75       2760.8  2015.0      18
# 755     14959.93          0.0  2015.0      30

# %% [markdown]
# spliting dataset for training and testing

# %%
x=data.drop('region',axis=1)
x
# Out:
#        AveragePrice  Total Volume           4046           4225          4770  \
# 1265        0.71000  9.163674e+05  611270.390000  205181.230000  14107.360000
# 1111        0.97000  1.356564e+05   35897.250000   84741.310000   2704.690000
# 1011        0.91000  4.696843e+05  284674.200000   78055.210000  27248.160000
# 488         0.92000  2.453526e+05    7245.610000  181784.280000  14761.530000
# 755         1.14000  5.693048e+05   30263.220000  417993.890000   1722.100000
# ...             ...           ...            ...            ...           ...
# 16463       1.07499  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16464       1.07499  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16465       1.07499  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16466       1.07499  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16467       1.07499  1.601879e+06  646438.654113  611437.502591  50405.495399
#
#           Small Bags    Large Bags  XLarge Bags         year
# 1265    82065.700000   3742.740000     0.000000  2015.000000
# 1111    12276.590000     36.520000     0.000000  2015.000000
# 1011    51793.300000  27913.450000     0.000000  2015.000000
# 488     20669.590000  18130.750000  2760.800000  2015.000000
# 755    104365.660000  14959.930000     0.000000  2015.000000
# ...              ...           ...          ...          ...
# 16463  248773.595287  42642.049374  2181.771074  2015.162821
# 16464  248773.595287  42642.049374  2181.771074  2015.162821
# 16465  248773.595287  42642.049374  2181.771074  2015.162821
# 16466  248773.595287  42642.049374  2181.771074  2015.162821
# 16467  248773.595287  42642.049374  2181.771074  2015.162821
#
# [16468 rows x 9 columns]

# %%
y=data['region']

# %%
y
# Out:
# 1265     50
# 1111     44
# 1011     41
# 488      18
# 755      30
#          ..
# 16463     6
# 16464     6
# 16465     6
# 16466     6
# 16467     6
# Name: region, Length: 16468, dtype: int32

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((13174, 9), (13174,), (3294, 9), (3294,))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.20554967026536308

# %%
pred=lr.predict(x_test)
print('predicted result price:',pred)
print('actual price',y_test)
# Out:
# predicted result price: [7.38978571 7.38978571 7.38978571 ... 7.38978571 7.38978571 7.38978571]
# actual price 10671    6
# 4639     6
# 2189     6
# 6648     6
# 8511     6
#         ..
# 2973     6
# 7496     6
# 12409    6
# 16272    6
# 13561    6
# Name: region, Length: 3294, dtype: int32

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.1591453417227019

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
print('error')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared erroe:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# Mean absolute error: 2.7211617205111516
# Mean squared erroe: 36.18445043267202
# Root Mean Squared Error: 6.015351231031486

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_jobs=-1,random_state=14)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=14)

# %%
rf.fit
# Out:
# <bound method BaseForest.fit of RandomForestRegressor(n_jobs=-1, random_state=14)>

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16468 entries, 1265 to 16467
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  16468 non-null  float64
#  1   Total Volume  16468 non-null  float64
#  2   4046          16468 non-null  float64
#  3   4225          16468 non-null  float64
#  4   4770          16468 non-null  float64
#  5   Small Bags    16468 non-null  float64
#  6   Large Bags    16468 non-null  float64
#  7   XLarge Bags   16468 non-null  float64
#  8   year          16468 non-null  float64
#  9   region        16468 non-null  int32
# dtypes: float64(9), int32(1)
# memory usage: 1.3 MB

# %%
y=data['AveragePrice']
y
# Out:
# 1265     0.71000
# 1111     0.97000
# 1011     0.91000
# 488      0.92000
# 755      1.14000
#           ...
# 16463    1.07499
# 16464    1.07499
# 16465    1.07499
# 16466    1.07499
# 16467    1.07499
# Name: AveragePrice, Length: 16468, dtype: float64

# %%
x=data.drop('AveragePrice',axis=1)
x
# Out:
#        Total Volume           4046           4225          4770  \
# 1265   9.163674e+05  611270.390000  205181.230000  14107.360000
# 1111   1.356564e+05   35897.250000   84741.310000   2704.690000
# 1011   4.696843e+05  284674.200000   78055.210000  27248.160000
# 488    2.453526e+05    7245.610000  181784.280000  14761.530000
# 755    5.693048e+05   30263.220000  417993.890000   1722.100000
# ...             ...            ...            ...           ...
# 16463  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16464  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16465  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16466  1.601879e+06  646438.654113  611437.502591  50405.495399
# 16467  1.601879e+06  646438.654113  611437.502591  50405.495399
#
#           Small Bags    Large Bags  XLarge Bags         year  region
# 1265    82065.700000   3742.740000     0.000000  2015.000000      50
# 1111    12276.590000     36.520000     0.000000  2015.000000      44
# 1011    51793.300000  27913.450000     0.000000  2015.000000      41
# 488     20669.590000  18130.750000  2760.800000  2015.000000      18
# 755    104365.660000  14959.930000     0.000000  2015.000000      30
# ...              ...           ...          ...          ...     ...
# 16463  248773.595287  42642.049374  2181.771074  2015.162821       6
# 16464  248773.595287  42642.049374  2181.771074  2015.162821       6
# 16465  248773.595287  42642.049374  2181.771074  2015.162821       6
# 16466  248773.595287  42642.049374  2181.771074  2015.162821       6
# 16467  248773.595287  42642.049374  2181.771074  2015.162821       6
#
# [16468 rows x 9 columns]

# %%
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((13174, 9), (13174,), (3294, 9), (3294,))

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9365513054037644
# [[10  0  0 ...  0  0  0]
#  [ 0  4  0 ...  0  0  0]
#  [ 0  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0  4  0]
#  [ 0  3  0 ...  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.07      1.00      0.13        10
#            1       0.10      1.00      0.18         4
#            2       0.55      0.92      0.69        13
#            3       0.00      0.00      0.00        15
#            4       0.64      1.00      0.78        14
#            5       0.00      0.00      0.00        15
#            6       1.00      1.00      1.00      3012
#            7       0.00      0.00      0.00         5
#            8       0.00      0.00      0.00         5
#            9       0.00      0.00      0.00         7
#           10       0.00      0.00      0.00         5
#           11       0.00      0.00      0.00         4
#           12       0.00      0.00      0.00         8
#           13       0.00      0.00      0.00         3
#           14       1.00      0.50      0.67         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         3
#           17       0.00      0.00      0.00         6
#           18       0.00      0.00      0.00         3
#           19       0.00      0.00      0.00         8
#           20       0.00      0.00      0.00         3
#           21       0.00      0.00      0.00         1
#           22       0.00      0.00      0.00         9
#           23       0.00      0.00      0.00         4
#           24       0.67      1.00      0.80         2
#           25       0.00      0.00      0.00         7
#           26       1.00      1.00      1.00         7
#           27       1.00      1.00      1.00         1
#           28       0.00      0.00      0.00         9
#           29       0.00      0.00      0.00         4
#           30       0.00      0.00      0.00         3
#           31       0.40      0.91      0.56        11
#           32       0.00      0.00      0.00         5
#           33       0.00      0.00      0.00         2
#           34       0.00      0.00      0.00         3
#           35       0.00      0.00      0.00         4
#           36       0.00      0.00      0.00         5
#           37       0.00      0.00      0.00         3
#           38       0.00      0.00      0.00         9
#           39       0.00      0.00      0.00         2
#           40       0.00      0.00      0.00         3
#           41       0.00      0.00      0.00         3
#           42       0.67      1.00      0.80         4
#           43       0.67      1.00      0.80         2
#           44       0.00      0.00      0.00        10
#           45       0.00      0.00      0.00         5
#           46       0.00      0.00      0.00         4
#           47       0.00      0.00      0.00         9
#           48       1.00      1.00      1.00         4
#           49       1.00      0.80      0.89         5
#           50       0.00      0.00      0.00         7
#
#     accuracy                           0.94      3294
#    macro avg       0.19      0.26      0.20      3294
# weighted avg       0.93      0.94      0.93      3294

# %%
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9911961141469339
# [[ 8  0  0 ...  0  0  0]
#  [ 0  4  0 ...  0  0  0]
#  [ 0  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0  5  0]
#  [ 0  0  0 ...  0  0  5]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       1.00      1.00      1.00         4
#            2       0.92      0.92      0.92        13
#            3       0.94      1.00      0.97        15
#            4       1.00      0.86      0.92        14
#            5       0.94      1.00      0.97        15
#            6       1.00      1.00      1.00      3012
#            7       1.00      0.80      0.89         5
#            8       0.83      1.00      0.91         5
#            9       1.00      1.00      1.00         7
#           10       1.00      0.80      0.89         5
#           11       1.00      1.00      1.00         4
#           12       0.83      0.62      0.71         8
#           13       0.75      1.00      0.86         3
#           14       1.00      1.00      1.00         2
#           15       1.00      0.50      0.67         2
#           16       0.67      0.67      0.67         3
#           17       1.00      0.83      0.91         6
#           18       1.00      0.67      0.80         3
#           19       1.00      0.88      0.93         8
#           20       0.67      0.67      0.67         3
#           21       1.00      1.00      1.00         1
#           22       0.90      1.00      0.95         9
#           23       1.00      1.00      1.00         4
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         7
#           26       1.00      1.00      1.00         7
#           27       1.00      1.00      1.00         1
#           28       0.89      0.89      0.89         9
#           29       0.33      0.25      0.29         4
#           30       0.75      1.00      0.86         3
#           31       0.92      1.00      0.96        11
#           32       0.80      0.80      0.80         5
#           33       1.00      1.00      1.00         2
#           34       0.33      0.33      0.33         3
#           35       0.80      1.00      0.89         4
#           36       1.00      1.00      1.00         5
#           37       1.00      1.00      1.00         3
#           38       0.82      1.00      0.90         9
#           39       1.00      1.00      1.00         2
#           40       0.75      1.00      0.86         3
#           41       0.60      1.00      0.75         3
#           42       1.00      1.00      1.00         4
#           43       1.00      1.00      1.00         2
#           44       1.00      1.00      1.00        10
#           45       1.00      1.00      1.00         5
#           46       0.75      0.75      0.75         4
#           47       0.70      0.78      0.74         9
#           48       1.00      1.00      1.00         4
#           49       0.83      1.00      0.91         5
#           50       1.00      0.71      0.83         7
#
#     accuracy                           0.99      3294
#    macro avg       0.89      0.89      0.89      3294
# weighted avg       0.99      0.99      0.99      3294

# %%
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=dtc.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.9911961141469339
# [[ 8  0  0 ...  0  0  0]
#  [ 0  4  0 ...  0  0  0]
#  [ 0  0 12 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  4  0  0]
#  [ 0  0  0 ...  0  5  0]
#  [ 0  0  0 ...  0  0  5]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        10
#            1       1.00      1.00      1.00         4
#            2       0.92      0.92      0.92        13
#            3       0.94      1.00      0.97        15
#            4       1.00      0.86      0.92        14
#            5       0.94      1.00      0.97        15
#            6       1.00      1.00      1.00      3012
#            7       1.00      0.80      0.89         5
#            8       0.83      1.00      0.91         5
#            9       1.00      1.00      1.00         7
#           10       1.00      0.80      0.89         5
#           11       1.00      1.00      1.00         4
#           12       0.83      0.62      0.71         8
#           13       0.75      1.00      0.86         3
#           14       1.00      1.00      1.00         2
#           15       1.00      0.50      0.67         2
#           16       0.67      0.67      0.67         3
#           17       1.00      0.83      0.91         6
#           18       1.00      0.67      0.80         3
#           19       1.00      0.88      0.93         8
#           20       0.67      0.67      0.67         3
#           21       1.00      1.00      1.00         1
#           22       0.90      1.00      0.95         9
#           23       1.00      1.00      1.00         4
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         7
#           26       1.00      1.00      1.00         7
#           27       1.00      1.00      1.00         1
#           28       0.89      0.89      0.89         9
#           29       0.33      0.25      0.29         4
#           30       0.75      1.00      0.86         3
#           31       0.92      1.00      0.96        11
#           32       0.80      0.80      0.80         5
#           33       1.00      1.00      1.00         2
#           34       0.33      0.33      0.33         3
#           35       0.80      1.00      0.89         4
#           36       1.00      1.00      1.00         5
#           37       1.00      1.00      1.00         3
#           38       0.82      1.00      0.90         9
#           39       1.00      1.00      1.00         2
#           40       0.75      1.00      0.86         3
#           41       0.60      1.00      0.75         3
#           42       1.00      1.00      1.00         4
#           43       1.00      1.00      1.00         2
#           44       1.00      1.00      1.00        10
#           45       1.00      1.00      1.00         5
#           46       0.75      0.75      0.75         4
#           47       0.70      0.78      0.74         9
#           48       1.00      1.00      1.00         4
#           49       0.83      1.00      0.91         5
#           50       1.00      0.71      0.83         7
#
#     accuracy                           0.99      3294
#    macro avg       0.89      0.89      0.89      3294
# weighted avg       0.99      0.99      0.99      3294
